# %%
#Pandas Basics


import pandas as pd

# %%
#1-dimensional array

n1 = pd.Series([1,2,3,4,5,6,7],index = ['a','b','c','d','e','f','g'])
n1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# g    7
# dtype: int64

# %%
dict1 ={'a':10,'b':20,'c':30,'d':40}

# %%
s1 = pd.Series(dict1)
s1
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
#2-dimensional array
#Data Frame

student_details = {'Student_Name':['Raju','Shyam','Jyoshna','Sam'],'Marks':[52,58,83,97]}

# %%
pd.DataFrame(student_details)
# Out:
#   Student_Name  Marks
# 0         Raju     52
# 1        Shyam     58
# 2      Jyoshna     83
# 3          Sam     97

# %%
import pandas as pd

# %%
read_file = pd.read_csv (r'C:\Users\Toshiba\Downloads\1000Records.csv')

# %%
read_file.head()
# Out:
#    Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0  850297         Ms.     Shawna              W       Buck      F
# 1  304721         Mr.  Nathaniel              Z      Burke      M
# 2  412317        Drs.  Elisabeth              W     Foster      F
# 3  621375        Mrs.     Briana              C  Lancaster      F
# 4  787549        Hon.    Estella              L     Potter      F
#
#                         E Mail      Father's Name     Mother's Name  \
# 0        shawna.buck@gmail.com       Rosario Buck       Keisha Buck
# 1  nathaniel.burke@walmart.com      Derrick Burke      Phoebe Burke
# 2   elisabeth.foster@gmail.com       Irwin Foster      Janie Foster
# 3   briana.lancaster@yahoo.com  Jeffrey Lancaster  Shelby Lancaster
# 4     estella.potter@gmail.com      Booker Potter    Katelyn Potter
#
#   Mother's Maiden Name  ...          SSN    Phone No.   Place Name  \
# 0            Hendricks  ...  222-11-7603  702-771-7149   Las Vegas
# ...

# %%
read_file.head(20)
# Out:
#     Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0   850297         Ms.     Shawna              W       Buck      F
# 1   304721         Mr.  Nathaniel              Z      Burke      M
# 2   412317        Drs.  Elisabeth              W     Foster      F
# 3   621375        Mrs.     Briana              C  Lancaster      F
# 4   787549        Hon.    Estella              L     Potter      F
# 5   520092         Mr.     Lamont              L      Woods      M
# 6   795934         Ms.    Melinda              L      Lopez      F
# 7   159108        Mrs.     Shanna              U      Silva      F
# 8   330816         Ms.    Jasmine              J    Freeman      F
# 9   532002         Ms.      Madge              V    Sargent      F
# 10  612850         Ms.    Bethany              Z      Cline      F
# 11  483751       Prof.       Reid              F   Randolph      M
# 12  252938        Hon.    Antoine              H      Wiley      M
# ...

# %%
read_file.tail()
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 995  568435         Ms.     Bonnie              K      Baker      F
# 996  597409         Mr.       Luke              S     Turner      M
# 997  359608        Hon.        Eva              S     Holman      F
# 998  803426        Mrs.    Maritza              H  Christian      F
# 999  669618        Drs.    Phyllis              H     Dudley      F
#
#                               E Mail   Father's Name        Mother's Name  \
# 995              bonnie.baker@bp.com   Edwardo Baker        Pauline Baker
# 996          luke.turner@charter.net   Javier Turner        Nicole Turner
# 997           eva.holman@hotmail.com      Coy Holman         Haley Holman
# 998  maritza.christian@microsoft.com  Dion Christian  Stephanie Christian
# 999       phyllis.dudley@yahoo.co.in   Jarrod Dudley       Latisha Dudley
#
#     Mother's Maiden Name  ...          SSN    Phone No.   Place Name  \
# ...

# %%
read_file.tail(15)
# Out:
#      Emp ID Name Prefix First Name Middle Initial   Last Name Gender  \
# 985  953997         Mr.     Graham              F  Hutchinson      M
# 986  149818        Mrs.    Ophelia              Z        Pena      F
# 987  352882         Dr.        Lon              P      Harper      M
# 988  760995         Mr.      Irvin              V        Witt      M
# 989  873626        Mrs.      Sheri              A      Spears      F
# 990  247051         Ms.    Alberta              A        Page      F
# 991  715045        Drs.      Kerri              Q      Santos      F
# 992  601808         Mr.       Olin              N        Case      M
# 993  569286         Mr.     Stefan              L      Jacobs      M
# 994  172440         Dr.       Cody              H     Allison      M
# 995  568435         Ms.     Bonnie              K       Baker      F
# 996  597409         Mr.       Luke              S      Turner      M
# 997  359608        Hon.        Eva              S      Holman      F
# ...

# %%
read_file.describe()
# Out:
#               Emp ID  Age in Yrs.  Weight in Kgs.  Year of Joining  \
# count    1000.000000  1000.000000     1000.000000      1000.000000
# mean   549097.583000    40.377250       59.409000      2006.992000
# std    264810.879315    11.107729       13.900322         8.565588
# min    114425.000000    21.040000       40.000000      1980.000000
# 25%    307757.000000    30.925000       49.000000      2002.000000
# 50%    543073.000000    40.730000       57.000000      2009.000000
# 75%    788450.250000    49.852500       68.000000      2014.000000
# max    999475.000000    59.980000       90.000000      2017.000000
#
#        Month of Joining  Day of Joining  Age in Company (Years)  \
# count       1000.000000     1000.000000             1000.000000
# mean           6.415000       16.481000               10.093720
# std            3.428488        8.831514                8.568863
# min            1.000000        1.000000                0.000000
# ...

# %%
read_file.head()
# Out:
#    Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0  850297         Ms.     Shawna              W       Buck      F
# 1  304721         Mr.  Nathaniel              Z      Burke      M
# 2  412317        Drs.  Elisabeth              W     Foster      F
# 3  621375        Mrs.     Briana              C  Lancaster      F
# 4  787549        Hon.    Estella              L     Potter      F
#
#                         E Mail      Father's Name     Mother's Name  \
# 0        shawna.buck@gmail.com       Rosario Buck       Keisha Buck
# 1  nathaniel.burke@walmart.com      Derrick Burke      Phoebe Burke
# 2   elisabeth.foster@gmail.com       Irwin Foster      Janie Foster
# 3   briana.lancaster@yahoo.com  Jeffrey Lancaster  Shelby Lancaster
# 4     estella.potter@gmail.com      Booker Potter    Katelyn Potter
#
#   Mother's Maiden Name  ...          SSN    Phone No.   Place Name  \
# 0            Hendricks  ...  222-11-7603  702-771-7149   Las Vegas
# ...

# %%
result = read_file.iloc[5:20,0:7]

# %%
result
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 5   520092         Mr.     Lamont              L     Woods      M
# 6   795934         Ms.    Melinda              L     Lopez      F
# 7   159108        Mrs.     Shanna              U     Silva      F
# 8   330816         Ms.    Jasmine              J   Freeman      F
# 9   532002         Ms.      Madge              V   Sargent      F
# 10  612850         Ms.    Bethany              Z     Cline      F
# 11  483751       Prof.       Reid              F  Randolph      M
# 12  252938        Hon.    Antoine              H     Wiley      M
# 13  966375         Dr.     Mathew              O     Hodge      M
# 14  707520         Mr.   Bernardo              L    Austin      M
# 15  673049         Dr.       Cole              E    Jensen      M
# 16  265124         Ms.      Tonia              J     Burns      F
# 17  300693         Mr.        Tod              N   Holcomb      M
# ...

# %%
read_file.head()
# Out:
#    Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0  850297         Ms.     Shawna              W       Buck      F
# 1  304721         Mr.  Nathaniel              Z      Burke      M
# 2  412317        Drs.  Elisabeth              W     Foster      F
# 3  621375        Mrs.     Briana              C  Lancaster      F
# 4  787549        Hon.    Estella              L     Potter      F
#
#                         E Mail      Father's Name     Mother's Name  \
# 0        shawna.buck@gmail.com       Rosario Buck       Keisha Buck
# 1  nathaniel.burke@walmart.com      Derrick Burke      Phoebe Burke
# 2   elisabeth.foster@gmail.com       Irwin Foster      Janie Foster
# 3   briana.lancaster@yahoo.com  Jeffrey Lancaster  Shelby Lancaster
# 4     estella.potter@gmail.com      Booker Potter    Katelyn Potter
#
#   Mother's Maiden Name  ...          SSN    Phone No.   Place Name  \
# 0            Hendricks  ...  222-11-7603  702-771-7149   Las Vegas
# ...

# %%
result = read_file[read_file['Gender'] == 'F']

# %%
result
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0    850297         Ms.     Shawna              W       Buck      F
# 2    412317        Drs.  Elisabeth              W     Foster      F
# 3    621375        Mrs.     Briana              C  Lancaster      F
# 4    787549        Hon.    Estella              L     Potter      F
# 6    795934         Ms.    Melinda              L      Lopez      F
# ..      ...         ...        ...            ...        ...    ...
# 991  715045        Drs.      Kerri              Q     Santos      F
# 995  568435         Ms.     Bonnie              K      Baker      F
# 997  359608        Hon.        Eva              S     Holman      F
# 998  803426        Mrs.    Maritza              H  Christian      F
# 999  669618        Drs.    Phyllis              H     Dudley      F
#
#                               E Mail      Father's Name        Mother's Name  \
# ...

# %%
result1 = read_file[(read_file['Gender'] == 'F') & (read_file['State'] == 'CT')]

# %%
result1
# Out:
#      Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 515  554345         Ms.     Ofelia              J     Rivers      F
# 578  670526        Mrs.     Adrian              W     Dunlap      F
# 665  188409         Ms.    Pearlie              M     Bryant      F
# 870  249410         Ms.     Yvette              C     Rivers      F
# 977  537235         Ms.     Cheryl              M     French      F
# 998  803426        Mrs.    Maritza              H  Christian      F
#
#                               E Mail    Father's Name        Mother's Name  \
# 515          ofelia.rivers@gmail.com  Anderson Rivers        Imelda Rivers
# 578        adrian.dunlap@hotmail.com     Lamar Dunlap     Charlotte Dunlap
# 665         pearlie.bryant@gmail.com      Vito Bryant          Kari Bryant
# 870            yvette.rivers@ibm.com       Hal Rivers        Alison Rivers
# 977            cheryl.french@aol.com     Rusty French        Lorena French
# ...
